# %% [markdown]
# <a href="https://colab.research.google.com/github/sudo-change/ML/blob/main/2_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-44d589d5-41dc-4b57-a29c-86cf84ac98e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44d589d5-41dc-4b57-a29c-86cf84ac98e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 64 bytes

# %%
# !kaggle competitions download -c titanic
# Out:
# ...
#   0% 0.00/3.18k [00:00<?, ?B/s]
# 100% 3.18k/3.18k [00:00<00:00, 2.76MB/s]
# ...
#   0% 0.00/59.8k [00:00<?, ?B/s]
# 100% 59.8k/59.8k [00:00<00:00, 62.2MB/s]
# test.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.Survived.unique()
# Out:
# array([0, 1])

# %%
(df.Survived==0).sum()
# Out:
# 549

# %%
cond = df.Sex=="male"
cond.mean()
# Out:
# 0.6475869809203143

# %%
cond
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2])

# %%
df.Fare.nunique()
# Out:
# 248

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[df.Pclass==1].head()
# Out:
#     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1             2         1       1  ...  71.2833   C85         C
# 3             4         1       1  ...  53.1000  C123         S
# 6             7         0       1  ...  51.8625   E46         S
# 11           12         1       1  ...  26.5500  C103         S
# 23           24         1       1  ...  35.5000    A6         S
#
# [5 rows x 12 columns]

# %%
df[(df.Pclass==1)&(df.Sex=='male')].head()
# Out:
#     PassengerId  Survived  Pclass  ...      Fare        Cabin  Embarked
# 6             7         0       1  ...   51.8625          E46         S
# 23           24         1       1  ...   35.5000           A6         S
# 27           28         0       1  ...  263.0000  C23 C25 C27         S
# 30           31         0       1  ...   27.7208          NaN         C
# 34           35         0       1  ...   82.1708          NaN         C
#
# [5 rows x 12 columns]

# %% [markdown]
# # loc and iloc

# %%
df = df.sample(frac=1)
df.head()
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 158          159         0       3  ...   8.6625   NaN         S
# 788          789         1       3  ...  20.5750   NaN         S
# 735          736         0       3  ...  16.1000   NaN         S
# 513          514         1       1  ...  59.4000   NaN         C
# 865          866         1       2  ...  13.0000   NaN         S
#
# [5 rows x 12 columns]

# %%
df.loc[788]
# Out:
# PassengerId                           789
# Survived                                1
# Pclass                                  3
# Name           Dean, Master. Bertram Vere
# Sex                                  male
# Age                                     1
# SibSp                                   1
# Parch                                   2
# Ticket                          C.A. 2315
# Fare                               20.575
# Cabin                                 NaN
# Embarked                                S
# Name: 788, dtype: object

# %%
df.loc[:2]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 158          159         0       3  ...   8.6625   NaN         S
# 788          789         1       3  ...  20.5750   NaN         S
# 735          736         0       3  ...  16.1000   NaN         S
# 513          514         1       1  ...  59.4000   NaN         C
# 865          866         1       2  ...  13.0000   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 9             10         1       2  ...  30.0708   NaN         C
# 286          287         1       3  ...   9.5000   NaN         S
# 667          668         0       3  ...   7.7750   NaN         S
# 40            41         0       3  ...   9.4750   NaN         S
# 2              3         1       3  ...   7.9250   NaN         S
#
# [288 rows x 12 columns]

# %%
df.iloc[789]
# Out:
# PassengerId                   761
# Survived                        0
# Pclass                          3
# Name           Garfirth, Mr. John
# Sex                          male
# Age                           NaN
# SibSp                           0
# Parch                           0
# Ticket                     358585
# Fare                         14.5
# Cabin                         NaN
# Embarked                        S
# Name: 760, dtype: object

# %%
df.iloc[:2]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 158          159         0       3  ...   8.6625   NaN         S
# 788          789         1       3  ...  20.5750   NaN         S
#
# [2 rows x 12 columns]

# %%
df.Name
# Out:
# 158                                  Smiljanic, Mr. Mile
# 788                           Dean, Master. Bertram Vere
# 735                                 Williams, Mr. Leslie
# 513       Rothschild, Mrs. Martin (Elizabeth L. Barrett)
# 865                             Bystrom, Mrs. (Karolina)
#                              ...
# 799    Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 531                                    Toufik, Mr. Nakli
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# 805                            Johansson, Mr. Karl Johan
# 45                              Rogers, Mr. William John
# Name: Name, Length: 891, dtype: object

# %%
df['Last_Name'] = df["Name"].map(lambda x:x.split(',')[0])
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked     Last_Name
# 764          765         0       3  ...   NaN        S        Eklund
# 73            74         0       3  ...   NaN        C  Chronopoulos
# 766          767         0       1  ...   NaN        C         Brewe
# 521          522         0       3  ...   NaN        S          Vovk
# 886          887         0       2  ...   NaN        S      Montvila
# 440          441         1       2  ...   NaN        S          Hart
# 864          865         0       2  ...   NaN        S          Gill
# 156          157         1       3  ...   NaN        Q       Gilnagh
# 635          636         1       2  ...   NaN        S         Davis
# 251          252         0       3  ...    G6        S         Strom
#
# [10 rows x 13 columns]
